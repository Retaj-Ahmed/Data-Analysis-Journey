# %%
import pandas as pd

# %%
people = {
    "first": ["Retaj", "Ahmed", "Marwa"],   
    "second": ["Ahmed", "Adel", "Salah"],  
    "email": ["retagahmed@gmail.com", "ahmedadel@gmail.com", "marwasalah@gmail.com"]
}

# %%
people['email']
# Out:
# ['retagahmed@gmail.com', 'ahmedadel@gmail.com', 'marwasalah@gmail.com']

# %%
df = pd.DataFrame(people)
df
# Out:
#    first second                 email
# 0  Retaj  Ahmed  retagahmed@gmail.com
# 1  Ahmed   Adel   ahmedadel@gmail.com
# 2  Marwa  Salah  marwasalah@gmail.com

# %%
df['email']
# Out:
# 0    retagahmed@gmail.com
# 1     ahmedadel@gmail.com
# 2    marwasalah@gmail.com
# Name: email, dtype: object

# %%
df.email
# Out:
# 0    retagahmed@gmail.com
# 1     ahmedadel@gmail.com
# 2    marwasalah@gmail.com
# Name: email, dtype: object

# %% [markdown]
# is the same thing

# %%
type(df['email'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# #Series is single column

# %%
df[['second','email']]
# Out:
#   second                 email
# 0  Ahmed  retagahmed@gmail.com
# 1   Adel   ahmedadel@gmail.com
# 2  Salah  marwasalah@gmail.com

# %%
#to get columns
df.columns
# Out:
# Index(['first', 'second', 'email'], dtype='object')

# %% [markdown]
# # هيعرض لك بيانات الشخص صاحب الإيميل ده
# df.loc['retagahmed@gmail.com']

# %%
#to get rows
df.iloc[1]
# Out:
# first                   Ahmed
# second                   Adel
# email     ahmedadel@gmail.com
# Name: 1, dtype: object

# %%
#to get multiple rows
df.iloc[[1,2]]
# Out:
#    first second                 email
# 1  Ahmed   Adel   ahmedadel@gmail.com
# 2  Marwa  Salah  marwasalah@gmail.com

# %%
#to get multiple rows with select specific location columns
df.iloc[[1,2],2]
# Out:
# 1     ahmedadel@gmail.com
# 2    marwasalah@gmail.com
# Name: email, dtype: object

# %% [markdown]
# iloc searching by integer location
# loc searching by lable

# %%
df.loc[[1,2],['email','second']]
# Out:
#                   email second
# 1   ahmedadel@gmail.com   Adel
# 2  marwasalah@gmail.com  Salah

# %%
df.loc[0:2,'first']
# Out:
# 0    Retaj
# 1    Ahmed
# 2    Marwa
# Name: first, dtype: object

# %%
df.loc[0:2,'first':]
# Out:
#    first second                 email
# 0  Retaj  Ahmed  retagahmed@gmail.com
# 1  Ahmed   Adel   ahmedadel@gmail.com
# 2  Marwa  Salah  marwasalah@gmail.com

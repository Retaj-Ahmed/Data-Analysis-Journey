# %%
import pandas as pd

# %%
people = {
    "first": ["Retaj", "Ahmed", "Marwa"],   
    "second": ["Ahmed", "Adel", "Salah"],  
    "email": ["retagahmed@gmail.com", "ahmedadel@gmail.com", "marwasalah@gmail.com"]
}

# %%
people
# Out:
# {'first': ['Retaj', 'Ahmed', 'Marwa'],
#  'second': ['Ahmed', 'Adel', 'Salah'],
#  'email': ['retagahmed@gmail.com',
#   'ahmedadel@gmail.com',
#   'marwasalah@gmail.com']}

# %%
df = pd.DataFrame(people)
df
# Out:
#    first second                 email
# 0  Retaj  Ahmed  retagahmed@gmail.com
# 1  Ahmed   Adel   ahmedadel@gmail.com
# 2  Marwa  Salah  marwasalah@gmail.com

# %%
df.set_index('email')
# Out:
#                       first second
# email
# retagahmed@gmail.com  Retaj  Ahmed
# ahmedadel@gmail.com   Ahmed   Adel
# marwasalah@gmail.com  Marwa  Salah

# %%
df
# Out:
#    first second                 email
# 0  Retaj  Ahmed  retagahmed@gmail.com
# 1  Ahmed   Adel   ahmedadel@gmail.com
# 2  Marwa  Salah  marwasalah@gmail.com

# %%
#Index (Sorting)
df.set_index('email',inplace=True)

# %%
df
# Out:
#                       first second
# email
# retagahmed@gmail.com  Retaj  Ahmed
# ahmedadel@gmail.com   Ahmed   Adel
# marwasalah@gmail.com  Marwa  Salah

# %%
df.index
# Out:
# Index(['retagahmed@gmail.com', 'ahmedadel@gmail.com', 'marwasalah@gmail.com'], dtype='object', name='email')

# %%
df.loc['retagahmed@gmail.com']
# Out:
# first     Retaj
# second    Ahmed
# Name: retagahmed@gmail.com, dtype: object

# %%
df.loc['retagahmed@gmail.com','second']
# Out:
# 'Ahmed'

# %%
df.iloc[1]
# Out:
# first     Ahmed
# second     Adel
# Name: ahmedadel@gmail.com, dtype: object

# %%
df.reset_index(inplace=True)
df
# Out:
#                   email  first second
# 0  retagahmed@gmail.com  Retaj  Ahmed
# 1   ahmedadel@gmail.com  Ahmed   Adel
# 2  marwasalah@gmail.com  Marwa  Salah

# %%
df.loc[0]
# Out:
# email     retagahmed@gmail.com
# first                    Retaj
# second                   Ahmed
# Name: 0, dtype: object
